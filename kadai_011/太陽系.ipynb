# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# %%
repeat_array = array * 2
for value in repeat_array:
  print(value)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
list_length = len(array)
count = 0
while count < list_length * 2:
    for item in array:
        print(item)
        count += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
