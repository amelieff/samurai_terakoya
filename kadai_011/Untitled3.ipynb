# %%
array = ["水","金","地","火","木","土","天","海","冥"]

num = 1

while num < 3:
    for i in array:
        print(i)
    num += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
