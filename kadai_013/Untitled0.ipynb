# %%
def calc(item, tax):

  tax_amount = item * (tax / 100)
  total_price = item + tax_amount
  return total_price

item = 110
tax = 10

final_price = calc(item_price, consumption_tax_rate)
print(final_price)
# Out:
# 121.0
