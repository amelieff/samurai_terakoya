# %%
# 消費税を加算する
def calc_tax(value:int , tax:int) -> float:
  total_value = value * (1 + tax / 100)
  return total_value


total_value = calc_tax(100, 10)
print(total_value)
# Out:
# 110.00000000000001
