# %%
# 消費税を加算する
def add_tax(value:int , tax:int) -> float:
  total_value = value * (1 + tax / 100)
  return total_value


total_value = calc_tax(110, 10)
print(total_value)
# Out:
# 121.00000000000001
