# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def print_info(self):
    print(f"Name: {self.name}, Age: {self.age}")

human = Human("John", 30)
print(user.name)
print(user.age)
# Out:
# John
# 30
