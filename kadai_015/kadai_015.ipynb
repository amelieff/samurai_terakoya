# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(f"名前: {self.name}")
        print(f"年齢: {self.age}")

person = Human("山田太郎", 30)

person.printinfo()
# Out:
# 名前: 山田太郎
# 年齢: 30
