# %%
class Human:
  def __init__(self):
    self.name = ""
    self.age = 0

  def printinfo(self):
    print(self.name)
    print(self.age)

human_ins = Human()
human_ins.name = "tanaka"
human_ins.age = 25
human_ins.printinfo()
# Out:
# tanaka
# 25
