# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name)
    print(self.age)

human_ins = Human("tanaka", 25)
human_ins.printinfo()
# Out:
# tanaka
# 25
