# %%
import numpy as np
A = np.array([[0, 1], [2, 3], [4, 5]])
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
B = np.array([[0, 1, 2, 3], [4, 5, 6, 7]])
B
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
# 積の計算
product = np.dot(A,B)
product
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
# 最大値の出力
product.max()
# Out:
# np.int64(47)
