# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def check_adult(self):
        if self.age >= 20:
            print(f"{self.name}は大人です。")
        else:
            print(f"{self.name}は大人ではありません。")

humans = [
    Human("Alice", 25),
    Human("Bob", 18),
    Human("Charlie", 30),
    Human("David", 15)
]

for human in humans:
    human.check_adult()
# Out:
# Aliceは大人です。
# Bobは大人ではありません。
# Charlieは大人です。
# Davidは大人ではありません。
