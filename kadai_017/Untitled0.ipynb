# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def check_adult(self):
    if self.age >= 20:
      print(self.name + " is adult")
    else:
      print(self.name + " is not adult")

user1 = Human("hoge", 0)
user2 = Human("huga", 20)
user3 = Human("piyo", 100)

users = [user1, user2, user3]
for i in users:
  i.check_adult()
# Out:
# hoge is not adult
# huga is adult
# piyo is adult
