# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"Name: {self.name}, Age: {self.age}")

  def check_adult(self):
    if self.age >= 20:
      print(f"{self.name} is adult")
    else:
      print(f"{self.name} is child")

humanA = Human("Yukinobu", 42)
humanB = Human("Eri", 19)
humans = [humanA, humanB]

for human in humans:
  human.check_adult()
# Out:
# Yukinobu is adult
# Eri is child
